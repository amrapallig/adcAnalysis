# %%
# AG_ADC1
#plots rez sensitivity profiles
#fig10

# %%
import matplotlib.pyplot as plt # plotting
import numpy as np              # working with number arrays etc.
from netCDF4 import Dataset     # reading netcdf files
from matplotlib.patches import Patch
from matplotlib.lines import Line2D

# %%
# path for data
path_les= "/Users/amrapalli/Desktop/DATA_ADC_paper1/LES/"
path_adc= "/Users/amrapalli/Desktop/DATA_ADC_paper1/ADC/"

path_les= "/Users/amrapalli/Desktop/DATA_ADC_paper1/LES/"
path_adc= "/Users/amrapalli/Desktop/DATA_ADC_paper1/ADC/"

# %%
fig = plt.figure(figsize=(13,11))
t=96
t1=t-6  # 6 hr average
mks=15
mks1=12
lw=3

d=70
plt.subplot(221)

lesc1= Dataset(path_les+"Cooling16.nc", mode='r')

fh_1m=Dataset(path_adc+'output.0001-01-01_00.00_1m.nc', mode='r')  #_6 is repo 6, _4 is repo 5 with w3check-0 from 1
fh_2m=Dataset(path_adc+'output.0001-01-01_00.00_2m.nc', mode='r')   #_3 is with 1,1.5, _2 is with 10,15
fh_5m=Dataset(path_adc+'output.0001-01-01_00.00_5m.nc', mode='r')
fh_10m=Dataset(path_adc+'output.0001-01-01_00.00_10m.nc', mode='r')

mfc1_1m = Dataset(path_adc+'adcTurbulenceArrays_c16_1m.nc', mode='r')  
mfc1_2m = Dataset(path_adc+'adcTurbulenceArrays_c16_2m.nc', mode='r')  
mfc1_5m = Dataset(path_adc+'adcTurbulenceArrays_c16_5m.nc', mode='r')
mfc1_10m = Dataset(path_adc+'adcTurbulenceArrays_c16_10m.nc', mode='r')




plt.plot(np.mean(lesc1.variables["temp"][t1:t,:],axis=0),lesc1.variables["zm"][:],'-k',linewidth=lw)
plt.plot(np.nanmean(mfc1_1m.variables['temperature'][t1:t,0,:],axis=0),fh_1m.variables['zMid'][1,1,:],'--r',linewidth=lw)
plt.plot(np.nanmean(mfc1_2m.variables['temperature'][t1:t,0,:],axis=0),fh_2m.variables['zMid'][1,1,:],'--b',linewidth=lw)
plt.plot(np.nanmean(mfc1_5m.variables['temperature'][t1:t,0,:],axis=0),fh_5m.variables['zMid'][1,1,:],':*c',markersize=mks)
plt.plot(np.nanmean(mfc1_10m.variables['temperature'][t1:t,0,:],axis=0),fh_10m.variables['zMid'][1,1,:],':pm',markersize=mks1)
#plt.legend(['les','adc_1m','adc_2m','adc_5m','adc_10m'],loc=4)
plt.ylim(-d,1)
plt.xlim(13,20)
plt.grid()
plt.legend(['LES','ADC_1m','ADC_2m','ADC_5m','ADC_10m'],loc=4,fontsize=14)

temp=20+0.1*lesc1.variables["zm"][:]

plt.plot(temp,lesc1.variables["zm"][:],':k',linewidth=1)

# #plt.ticklabel_format(axis="x", style="sci", scilimits=(0,0))

plt.xlabel('$\overline{\\theta}$ $(^0C)$ ',fontsize=20)
plt.ylabel('$Depth$ $(m)$ ',fontsize=20)
plt.xticks(fontsize=20)
plt.yticks(fontsize=20)
#plt.text(18.5, -55,"(a)",fontsize=20)


plt.subplot(222)

plt.plot(np.mean(lesc1.variables["wt"][t1:t,:],axis=0),lesc1.variables["zm"][:],'-k',linewidth=lw)
plt.plot(np.nanmean(mfc1_1m.variables['wt'][t1:t,0,:-1]+mfc1_1m.variables['wt_spsD'][t1:t,0,:-1],axis=0),fh_1m.variables['zTop'][1,1,:],'--r',linewidth=lw)
plt.plot(np.nanmean(mfc1_2m.variables['wt'][t1:t,0,:-1]+mfc1_2m.variables['wt_spsD'][t1:t,0,:-1],axis=0),fh_2m.variables['zTop'][1,1,:],':b',linewidth=lw)
plt.plot(np.nanmean(mfc1_5m.variables['wt'][t1:t,0,:-1]+mfc1_5m.variables['wt_spsD'][t1:t,0,:-1],axis=0),fh_5m.variables['zTop'][1,1,:],':*c',markersize=mks)
plt.plot(np.nanmean(mfc1_10m.variables['wt'][t1:t,0,:-1]+mfc1_10m.variables['wt_spsD'][t1:t,0,:-1],axis=0),fh_10m.variables['zTop'][1,1,:],':pm',markersize=mks1)
plt.ylim(-d,1)
plt.xlabel('$\overline{w^\prime\\theta^\prime}$ $(K$ $m s^{-1})$',fontsize=20)
plt.grid()
plt.ticklabel_format(axis="x", style="sci", scilimits=(0,0))
plt.xticks(fontsize=20)
plt.yticks(fontsize=20)
plt.text(1.5e-4, -55,"(b)",fontsize=20)
plt.ylabel('$Depth$ $(m)$ ',fontsize=20)


plt.subplot(223)

plt.plot(np.mean(lesc1.variables["w2"][t1:t,:],axis=0),lesc1.variables["zt"][:],'-k',linewidth=lw)
plt.plot(np.nanmean(mfc1_1m.variables['w2'][t1:t,0,:-1],axis=0),fh_1m.variables['zTop'][1,1,:],'--r',linewidth=lw)
plt.plot(np.nanmean(mfc1_2m.variables['w2'][t1:t,0,:-1],axis=0),fh_2m.variables['zTop'][1,1,:],':b',linewidth=lw)
plt.plot(np.nanmean(mfc1_5m.variables['w2'][t1:t,0,:-1],axis=0),fh_5m.variables['zTop'][1,1,:],':*c',markersize=mks)
plt.plot(np.nanmean(mfc1_10m.variables['w2'][t1:t,0,:-1],axis=0),fh_10m.variables['zTop'][1,1,:],':pm',markersize=mks1)
#plt.legend(['les','adc_1m','adc_2m','adc_5m','adc_10m'],loc=4)
plt.ylim(-d,1)
plt.xlabel('$\overline{{w^\prime}^2}$  $(m^2/s^2)$ ',fontsize=20)
plt.grid()
plt.ticklabel_format(axis="x", style="sci", scilimits=(0,0))
plt.xticks(fontsize=20)
plt.yticks(fontsize=20)
plt.ylabel('$Depth$ $(m)$ ',fontsize=20)
plt.text(2.5e-4, -55,"(c)",fontsize=20)


plt.subplot(224)

plt.plot(np.mean(lesc1.variables["w3"][t1:t,:],axis=0),lesc1.variables["zm"][:],'-k',linewidth=lw)
plt.plot(np.nanmean(mfc1_1m.variables['w3'][t1:t,0,:-1],axis=0),fh_1m.variables['zMid'][1,1,:-1],'--r',linewidth=lw)
plt.plot(np.nanmean(mfc1_2m.variables['w3'][t1:t,0,:-1],axis=0),fh_2m.variables['zMid'][1,1,:-1],':b',linewidth=lw)
plt.plot(np.nanmean(mfc1_5m.variables['w3'][t1:t,0,:-1],axis=0),fh_5m.variables['zMid'][1,1,:-1],':*c',markersize=mks)
plt.plot(np.nanmean(mfc1_10m.variables['w3'][t1:t,0,:-1],axis=0),fh_10m.variables['zMid'][1,1,:-1],':pm',markersize=mks1)
#plt.legend(['les','adc_1m','adc_2m','adc_5m','adc_10m'],loc=4)
plt.ylim(-d,1)
plt.xlabel('$\overline{{w^\prime}^3}$ $(m^3/s^3)$ ',fontsize=20)
plt.grid()
plt.ticklabel_format(axis="x", style="sci", scilimits=(0,0))
plt.xticks(fontsize=20)
plt.yticks(fontsize=20)
plt.text(3e-6, -55,"(d)",fontsize=20)
# Out:
# Text(3e-06, -55, '(d)')

# %%
fig = plt.figure(figsize=(13,12))
t=96
t1=t-6  # 6 hr average
mks=15
mks1=12
lw=3

d=70
plt.subplot(221)

lesc1= Dataset(path_les+"Cooling16.nc", mode='r')

fh_1m=Dataset(path_adc+'output.0001-01-01_00.00_1m.nc', mode='r')  #_6 is repo 6, _4 is repo 5 with w3check-0 from 1
fh_2m=Dataset(path_adc+'output.0001-01-01_00.00_2m.nc', mode='r')   #_3 is with 1,1.5, _2 is with 10,15
fh_5m=Dataset(path_adc+'output.0001-01-01_00.00_5m.nc', mode='r')
fh_10m=Dataset(path_adc+'output.0001-01-01_00.00_10m.nc', mode='r')

mfc1_1m = Dataset(path_adc+'adcTurbulenceArrays_c16_1m.nc', mode='r')  
mfc1_2m = Dataset(path_adc+'adcTurbulenceArrays_c16_2m.nc', mode='r')  
mfc1_5m = Dataset(path_adc+'adcTurbulenceArrays_c16_5m.nc', mode='r')
mfc1_10m = Dataset(path_adc+'adcTurbulenceArrays_c16_10m.nc', mode='r')




plt.plot(np.mean(lesc1.variables["temp"][t1:t,:],axis=0),lesc1.variables["zm"][:],'-k',linewidth=lw)
plt.plot(np.nanmean(mfc1_1m.variables['temperature'][t1:t,0,:],axis=0),fh_1m.variables['zMid'][1,1,:],'--r',linewidth=lw)
plt.plot(np.nanmean(mfc1_2m.variables['temperature'][t1:t,0,:],axis=0),fh_2m.variables['zMid'][1,1,:],'--b',linewidth=lw)
plt.plot(np.nanmean(mfc1_5m.variables['temperature'][t1:t,0,:],axis=0),fh_5m.variables['zMid'][1,1,:],':*c',markersize=mks)
plt.plot(np.nanmean(mfc1_10m.variables['temperature'][t1:t,0,:],axis=0),fh_10m.variables['zMid'][1,1,:],':pm',markersize=mks1)
#plt.legend(['les','adc_1m','adc_2m','adc_5m','adc_10m'],loc=4)
plt.ylim(-d,1)
plt.xlim(13,20)
plt.grid()
plt.legend(['LES','ADC_1m','ADC_2m','ADC_5m','ADC_10m'],loc=4,fontsize=14)

temp=20+0.1*lesc1.variables["zm"][:]

plt.plot(temp,lesc1.variables["zm"][:],':k',linewidth=1)

# #plt.ticklabel_format(axis="x", style="sci", scilimits=(0,0))

plt.xlabel('$\overline{\\theta}$ $(^0C)$ ',fontsize=20)
plt.ylabel('$Depth$ $(m)$ ',fontsize=20)
plt.xticks(fontsize=20)
plt.yticks(fontsize=20)
plt.text(16, -55,"(a)",fontsize=20)


plt.subplot(222)




plt.plot(np.mean(lesc1.variables["wt"][t1:t,:],axis=0)/lesc1.variables["wt"][0,0],lesc1.variables["zm"][:],'-k',linewidth=lw)
plt.plot(np.nanmean(mfc1_1m.variables['wt'][t1:t,0,:-1]+mfc1_1m.variables['wt_spsD'][t1:t,0,:-1],axis=0)/lesc1.variables["wt"][0,0],fh_1m.variables['zTop'][1,1,:],'--r',linewidth=lw)
plt.plot(np.nanmean(mfc1_2m.variables['wt'][t1:t,0,:-1]+mfc1_2m.variables['wt_spsD'][t1:t,0,:-1],axis=0)/lesc1.variables["wt"][0,0],fh_2m.variables['zTop'][1,1,:],':b',linewidth=lw)
plt.plot(np.nanmean(mfc1_5m.variables['wt'][t1:t,0,:-1]+mfc1_5m.variables['wt_spsD'][t1:t,0,:-1],axis=0)/lesc1.variables["wt"][0,0],fh_5m.variables['zTop'][1,1,:],':*c',markersize=mks)
plt.plot(np.nanmean(mfc1_10m.variables['wt'][t1:t,0,:-1]+mfc1_10m.variables['wt_spsD'][t1:t,0,:-1],axis=0)/lesc1.variables["wt"][0,0],fh_10m.variables['zTop'][1,1,:],':pm',markersize=mks1)
plt.ylim(-d,1)
plt.xlabel('$\overline{w^\prime\\theta^\prime}/\overline{w^\prime\\theta^\prime}_{sfc}$',fontsize=20)
plt.grid()
plt.ticklabel_format(axis="x", style="sci", scilimits=(0,0))
plt.xticks(fontsize=20)
plt.yticks(fontsize=20)
plt.text(0.2, -55,"(b)",fontsize=20)
#plt.ylabel('$Depth$ $(m)$ ',fontsize=20)


plt.subplot(223)
def wstar_sfc(wb,h):
    ws=(wb*(-h))**(1/3)
    #wb=g*(alpha*wt-beta*ws)
    return np.nanmean(ws**2)

wstar2=wstar_sfc(lesc1.variables["wb"][t1:t,0],lesc1.variables["H"][t1:t])


plt.plot(np.mean(lesc1.variables["w2"][t1:t,:],axis=0)/wstar2,lesc1.variables["zt"][:],'-k',linewidth=lw)
plt.plot(np.nanmean(mfc1_1m.variables['w2'][t1:t,0,:-1],axis=0)/wstar2,fh_1m.variables['zTop'][1,1,:],'--r',linewidth=lw)
plt.plot(np.nanmean(mfc1_2m.variables['w2'][t1:t,0,:-1],axis=0)/wstar2,fh_2m.variables['zTop'][1,1,:],':b',linewidth=lw)
plt.plot(np.nanmean(mfc1_5m.variables['w2'][t1:t,0,:-1],axis=0)/wstar2,fh_5m.variables['zTop'][1,1,:],':*c',markersize=mks)
plt.plot(np.nanmean(mfc1_10m.variables['w2'][t1:t,0,:-1],axis=0)/wstar2,fh_10m.variables['zTop'][1,1,:],':pm',markersize=mks1)
#plt.legend(['les','adc_1m','adc_2m','adc_5m','adc_10m'],loc=4)
plt.ylim(-d,1)
plt.xlabel('$\overline{{w^\prime}^2}/w*^2$ ',fontsize=20)
plt.grid()
#plt.ticklabel_format(axis="x", style="sci", scilimits=(0,0))
plt.xticks(fontsize=20)
plt.yticks(fontsize=20)
plt.ylabel('$Depth$ $(m)$ ',fontsize=20)
plt.text(0.15, -55,"(c)",fontsize=20)


plt.subplot(224)

def wstar_sfc(wb,h):
    ws=(wb*(-h))**(1/3)
    #wb=g*(alpha*wt-beta*ws)
    return np.nanmean(ws**3)

wstar3=wstar_sfc(lesc1.variables["wb"][t1:t,0],lesc1.variables["H"][t1:t])

plt.plot(np.mean(lesc1.variables["w3"][t1:t,:],axis=0)/wstar3,lesc1.variables["zm"][:],'-k',linewidth=lw)
plt.plot(np.nanmean(mfc1_1m.variables['w3'][t1:t,0,:-1],axis=0)/wstar3,fh_1m.variables['zMid'][1,1,:-1],'--r',linewidth=lw)
plt.plot(np.nanmean(mfc1_2m.variables['w3'][t1:t,0,:-1],axis=0)/wstar3,fh_2m.variables['zMid'][1,1,:-1],':b',linewidth=lw)
plt.plot(np.nanmean(mfc1_5m.variables['w3'][t1:t,0,:-1],axis=0)/wstar3,fh_5m.variables['zMid'][1,1,:-1],':*c',markersize=mks)
plt.plot(np.nanmean(mfc1_10m.variables['w3'][t1:t,0,:-1],axis=0)/wstar3,fh_10m.variables['zMid'][1,1,:-1],':pm',markersize=mks1)
#plt.legend(['les','adc_1m','adc_2m','adc_5m','adc_10m'],loc=4)
plt.ylim(-d,1)
plt.xlabel('$\overline{{w^\prime}^3}/w*^3$ ',fontsize=20)
plt.grid()
#plt.ticklabel_format(axis="x", style="sci", scilimits=(0,0))
plt.xticks(fontsize=20)
plt.yticks(fontsize=20)
plt.text(0.1, -55,"(d)",fontsize=20)
plt.savefig("vertical_resolution_sensitivity_c16_2.eps")
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

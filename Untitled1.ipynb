# %%
#AG test

import matplotlib.pyplot as plt # plotting
import numpy as np              # working with number arrays etc.
from netCDF4 import Dataset     # reading netcdf files
from matplotlib.patches import Patch
from matplotlib.lines import Line2D
path_adc= "/Users/amrapalli/Desktop/DATA_ADC_paper1/rev_additional_plots/"

path_old= "/Users/amrapalli/Desktop/DATA_ADC_paper1/ADC/"
path_les= "/Users/amrapalli/Desktop/DATA_ADC_paper1/LES/"
les= Dataset(path_les+'Cooling16.nc', mode='r')

# %%
fig = plt.figure(figsize=(20,8))

d=70
plt.subplot(141)

mf_old= Dataset(path_old+'adcTurbulenceArrays_c16_1m.nc', mode='r')
mf= Dataset(path_adc+'adcTurbulenceArrays_c16_old.nc', mode='r')

fh=Dataset(path_adc+'output.0001-01-01_00.00.00.nc', mode='r')
plt.plot(mf_old.variables["temperature"][96,0,:],fh.variables["zMid"][0,0,:],':b',linewidth=2.5)
plt.plot(mf.variables["temperature"][96,0,:],fh.variables["zMid"][0,0,:],'--r',linewidth=2.5)
plt.plot((les.variables["temp"][96,:]),les.variables["zm"][:],'k',linewidth=2.5)

plt.ylim(-d,1); plt.xlim(13,20)
plt.xlabel('$\overline{\\theta}$ $(^0C)$',fontsize=20)
plt.ylabel('$Depth$ $(m)$ ',fontsize=20)
plt.grid()
plt.xticks(fontsize=20); plt.yticks(fontsize=20)
plt.legend(["old_data","oldcode","LES"])


plt.subplot(142)
mf_old= Dataset(path_old+'adcTurbulenceArrays_c16_1m.nc', mode='r')
mf= Dataset(path_adc+'adcTurbulenceArrays_c16_cslow_w_1.nc', mode='r')

fh=Dataset(path_adc+'output.0001-01-01_00.00.00.nc', mode='r')
plt.plot(mf_old.variables["temperature"][96,0,:],fh.variables["zMid"][0,0,:],'--r',linewidth=2.5)
plt.plot(mf.variables["temperature"][96,0,:],fh.variables["zMid"][0,0,:],'--c',linewidth=2.5)
plt.legend(["old_code_cslow_w_0.654","old_code_cslow_w_1"])
plt.ylim(-d,1); plt.xlim(13,20)
plt.xlabel('$\overline{\\theta}$ $(^0C)$',fontsize=20)
plt.grid()
plt.xticks(fontsize=20); plt.yticks(fontsize=20)

plt.subplot(143)
fh=Dataset(path_adc+'output.0001-01-01_00.00.00.nc', mode='r')

mf_old= Dataset(path_old+'adcTurbulenceArrays_c16_1m.nc', mode='r')
plt.plot(mf_old.variables["temperature"][96,0,:],fh.variables["zMid"][0,0,:],'--r',linewidth=2.5)

mf= Dataset(path_adc+'adcTurbulenceArrays_c16_cslow_w_1.nc', mode='r')
plt.plot(mf.variables["temperature"][96,0,:],fh.variables["zMid"][0,0,:],'--k',linewidth=2.5)

mf= Dataset(path_adc+'adcTurbulenceArrays_c16_tauVel_cslow_w_p654.nc', mode='r')
plt.plot(mf.variables["temperature"][96,0,:],fh.variables["zMid"][0,0,:],'--b',linewidth=2.5)

mf= Dataset(path_adc+'adcTurbulenceArrays_c16_tauVel_cslow_w_1.nc', mode='r')
plt.plot(mf.variables["temperature"][96,0,:],fh.variables["zMid"][0,0,:],':c',linewidth=2.5)





plt.legend(["old_code_cslow_w_0.654","old_code_cslow_w_1","new_code_cslow_w_0.654","new_code_cslow_w_1"])
plt.ylim(-d,1); plt.xlim(13,20)
plt.xlabel('$\overline{\\theta}$ $(^0C)$',fontsize=20)
plt.grid()
plt.xticks(fontsize=20); plt.yticks(fontsize=20)



plt.subplot(144)
fh=Dataset(path_adc+'output.0001-01-01_00.00.00.nc', mode='r')



plt.plot((les.variables["temp"][96,:]),les.variables["zm"][:],'k',linewidth=2.5)


mf= Dataset(path_adc+'adcTurbulenceArrays_c16_tauVel_cslow_w_p654.nc', mode='r')
plt.plot(mf.variables["temperature"][96,0,:],fh.variables["zMid"][0,0,:],'--r',linewidth=2.5)

mf= Dataset(path_adc+'adcTurbulenceArrays_c16_tauVel_cslow_w_1.nc', mode='r')
plt.plot(mf.variables["temperature"][96,0,:],fh.variables["zMid"][0,0,:],'--b',linewidth=2.5)

mf= Dataset(path_adc+'adcTurbulenceArrays_c16_tauVel_cslow_w_p1.nc', mode='r')
plt.plot(mf.variables["temperature"][96,0,:],fh.variables["zMid"][0,0,:],'--c',linewidth=2.5)



plt.legend(["LES","new_code_cslow_w_0.654","new_code_cslow_w_1","new_code_cslow_w_p1"])
plt.ylim(-d,1); plt.xlim(13,20)
plt.xlabel('$\overline{\\theta}$ $(^0C)$',fontsize=20)
plt.grid()
plt.xticks(fontsize=20); plt.yticks(fontsize=20)

plt.suptitle("c16")
# Out:
# Text(0.5, 0.98, 'c16')

# %%
fh=Dataset(path_adc+'output.0001-01-01_00.00.00.nc', mode='r')



plt.plot((les.variables["temp"][96,:]),les.variables["zm"][:],'k',linewidth=2.5)


mf= Dataset(path_adc+'adcTurbulenceArrays_c16_tauVel_cslow_w_p654.nc', mode='r')
plt.plot(mf.variables["temperature"][96,0,:],fh.variables["zMid"][0,0,:],'--r',linewidth=2.5)

mf= Dataset(path_adc+'adcTurbulenceArrays_c16_tauVel_cslow_w_1.nc', mode='r')
plt.plot(mf.variables["temperature"][96,0,:],fh.variables["zMid"][0,0,:],'--b',linewidth=2.5)

mf= Dataset(path_adc+'adcTurbulenceArrays_c16_tauVel_cslow_w_p1.nc', mode='r')
plt.plot(mf.variables["temperature"][96,0,:],fh.variables["zMid"][0,0,:],'--c',linewidth=2.5)

mf= Dataset(path_adc+'adcTurbulenceArrays_c16_tauVel_cslow_w_1_new.nc', mode='r')
plt.plot(mf.variables["temperature"][96,0,:],fh.variables["zMid"][0,0,:],'--g',linewidth=2.5)

mf= Dataset(path_adc+'adcTurbulenceArrays_c16_tauVel_cslow_w_p1_new.nc', mode='r')
plt.plot(mf.variables["temperature"][96,0,:],fh.variables["zMid"][0,0,:],':m',linewidth=2.5)

plt.legend(["LES","new_code_cslow_w_0.654","new_code_cslow_w_1","new_code_cslow_w_p1","time_corrrected_cslow_w_1","time_corrrected_cslow_w_p1"])
plt.ylim(-d,1); plt.xlim(13,20)
plt.xlabel('$\overline{\\theta}$ $(^0C)$',fontsize=20)
plt.grid()
plt.xticks(fontsize=20); plt.yticks(fontsize=20)

plt.suptitle("c16")
# Out:
# Text(0.5, 0.98, 'c16')

# %%
fig = plt.figure(figsize=(20,8))

plt.subplot(121)


fh=Dataset(path_adc+'output.0001-01-01_00.00.00.nc', mode='r')
plt.plot((les.variables["w2"][96,:]),les.variables["zt"][:],'k',linewidth=2.5)


mf= Dataset(path_adc+'adcTurbulenceArrays_c16_tauVel_cslow_w_p654.nc', mode='r')
plt.plot(mf.variables["w2"][96,0,:-1],fh.variables["zTop"][0,0,:],'--r',linewidth=2.5)

mf= Dataset(path_adc+'adcTurbulenceArrays_c16_tauVel_cslow_w_1.nc', mode='r')
plt.plot(mf.variables["w2"][96,0,:-1],fh.variables["zTop"][0,0,:],'--b',linewidth=2.5)

mf= Dataset(path_adc+'adcTurbulenceArrays_c16_tauVel_cslow_w_p1.nc', mode='r')
plt.plot(mf.variables["w2"][96,0,:-1],fh.variables["zTop"][0,0,:],'--c',linewidth=2.5)

mf= Dataset(path_adc+'adcTurbulenceArrays_c16_tauVel_cslow_w_1_new.nc', mode='r')
plt.plot(mf.variables["w2"][96,0,:-1],fh.variables["zTop"][0,0,:],'--g',linewidth=2.5)

mf= Dataset(path_adc+'adcTurbulenceArrays_c16_tauVel_cslow_w_p1_new.nc', mode='r')
plt.plot(mf.variables["w2"][96,0,:-1],fh.variables["zTop"][0,0,:],':m',linewidth=2.5)

plt.legend(["LES","new_code_cslow_w_0.654","new_code_cslow_w_1","new_code_cslow_w_p1","time_corrrected_cslow_w_1","time_corrrected_cslow_w_p1"])


plt.ylim(-d,1);
plt.grid()
plt.xticks(fontsize=20); plt.yticks(fontsize=20)

plt.title("w2")



plt.subplot(122)
fh=Dataset(path_adc+'output.0001-01-01_00.00.00.nc', mode='r')



plt.plot((les.variables["wt"][96,:]),les.variables["zt"][:],'k',linewidth=2.5)


mf= Dataset(path_adc+'adcTurbulenceArrays_c16_tauVel_cslow_w_p654.nc', mode='r')
plt.plot(mf.variables["wt"][96,0,:-1],fh.variables["zTop"][0,0,:],'--r',linewidth=2.5)

mf= Dataset(path_adc+'adcTurbulenceArrays_c16_tauVel_cslow_w_1.nc', mode='r')
plt.plot(mf.variables["wt"][96,0,:-1],fh.variables["zTop"][0,0,:],'--b',linewidth=2.5)

mf= Dataset(path_adc+'adcTurbulenceArrays_c16_tauVel_cslow_w_p1.nc', mode='r')
plt.plot(mf.variables["wt"][96,0,:-1],fh.variables["zTop"][0,0,:],'--c',linewidth=2.5)

mf= Dataset(path_adc+'adcTurbulenceArrays_c16_tauVel_cslow_w_1_new.nc', mode='r')
plt.plot(mf.variables["wt"][96,0,:-1],fh.variables["zTop"][0,0,:],'--g',linewidth=2.5)

mf= Dataset(path_adc+'adcTurbulenceArrays_c16_tauVel_cslow_w_p1_new.nc', mode='r')
plt.plot(mf.variables["wt"][96,0,:-1],fh.variables["zTop"][0,0,:],':m',linewidth=2.5)

plt.legend(["LES","new_code_cslow_w_0.654","new_code_cslow_w_1","new_code_cslow_w_p1","time_corrrected_cslow_w_1","time_corrrected_cslow_w_p1"])



plt.legend(["LES","new_code_cslow_w_0.654","new_code_cslow_w_1","new_code_cslow_w_p1"])
plt.ylim(-d,1);
plt.grid()
plt.xticks(fontsize=20); plt.yticks(fontsize=20)

plt.title("wt")
# Out:
# Text(0.5, 1.0, 'wt')

# %%
fig = plt.figure(figsize=(20,8))

plt.subplot(121)


fh=Dataset(path_adc+'output.0001-01-01_00.00.00.nc', mode='r')
plt.plot((les.variables["u2"][96,:]),les.variables["zt"][:],'k',linewidth=2.5)


mf= Dataset(path_adc+'adcTurbulenceArrays_c16_tauVel_cslow_w_p654.nc', mode='r')
plt.plot(mf.variables["u2"][96,0,:-1],fh.variables["zTop"][0,0,:],'--r',linewidth=2.5)

mf= Dataset(path_adc+'adcTurbulenceArrays_c16_tauVel_cslow_w_1.nc', mode='r')
plt.plot(mf.variables["u2"][96,0,:-1],fh.variables["zTop"][0,0,:],'--b',linewidth=2.5)

mf= Dataset(path_adc+'adcTurbulenceArrays_c16_tauVel_cslow_w_p1.nc', mode='r')
plt.plot(mf.variables["u2"][96,0,:-1],fh.variables["zTop"][0,0,:],'--c',linewidth=2.5)

mf= Dataset(path_adc+'adcTurbulenceArrays_c16_tauVel_cslow_w_1_new.nc', mode='r')
plt.plot(mf.variables["u2"][96,0,:-1],fh.variables["zTop"][0,0,:],'--g',linewidth=2.5)

mf= Dataset(path_adc+'adcTurbulenceArrays_c16_tauVel_cslow_w_p1_new.nc', mode='r')
plt.plot(mf.variables["u2"][96,0,:-1],fh.variables["zTop"][0,0,:],':m',linewidth=2.5)

plt.legend(["LES","new_code_cslow_w_0.654","new_code_cslow_w_1","new_code_cslow_w_p1","time_corrrected_cslow_w_1","time_corrrected_cslow_w_p1"])


plt.ylim(-d,1);
plt.grid()
plt.xticks(fontsize=20); plt.yticks(fontsize=20)

plt.title("u2")

plt.subplot(122)


fh=Dataset(path_adc+'output.0001-01-01_00.00.00.nc', mode='r')
plt.plot((les.variables["v2"][96,:]),les.variables["zt"][:],'k',linewidth=2.5)


mf= Dataset(path_adc+'adcTurbulenceArrays_c16_tauVel_cslow_w_p654.nc', mode='r')
plt.plot(mf.variables["v2"][96,0,:-1],fh.variables["zTop"][0,0,:],'--r',linewidth=2.5)

mf= Dataset(path_adc+'adcTurbulenceArrays_c16_tauVel_cslow_w_1.nc', mode='r')
plt.plot(mf.variables["v2"][96,0,:-1],fh.variables["zTop"][0,0,:],'--b',linewidth=2.5)

mf= Dataset(path_adc+'adcTurbulenceArrays_c16_tauVel_cslow_w_p1.nc', mode='r')
plt.plot(mf.variables["v2"][96,0,:-1],fh.variables["zTop"][0,0,:],'--c',linewidth=2.5)

mf= Dataset(path_adc+'adcTurbulenceArrays_c16_tauVel_cslow_w_1_new.nc', mode='r')
plt.plot(mf.variables["v2"][96,0,:-1],fh.variables["zTop"][0,0,:],'--g',linewidth=2.5)

mf= Dataset(path_adc+'adcTurbulenceArrays_c16_tauVel_cslow_w_p1_new.nc', mode='r')
plt.plot(mf.variables["v2"][96,0,:-1],fh.variables["zTop"][0,0,:],':m',linewidth=2.5)

plt.legend(["LES","new_code_cslow_w_0.654","new_code_cslow_w_1","new_code_cslow_w_p1"])
plt.ylim(-d,1);
plt.grid()
plt.xticks(fontsize=20); plt.yticks(fontsize=20)

plt.title("v2")
# Out:
# Text(0.5, 1.0, 'v2')

# %%
fh=Dataset(path_adc+'output.0001-01-01_00.00.00.nc', mode='r')

mf_old= Dataset(path_old+'adcTurbulenceArrays_c16_1m.nc', mode='r')
plt.plot(mf_old.variables["w2"][96,0,:-1],fh.variables["zTop"][0,0,:],'--r',linewidth=2.5)

mf= Dataset(path_adc+'adcTurbulenceArrays_c16_cslow_w_1.nc', mode='r')
plt.plot(mf.variables["w2"][96,0,:-1],fh.variables["zTop"][0,0,:],'--k',linewidth=2.5)

mf= Dataset(path_adc+'adcTurbulenceArrays_c16_tauVel_cslow_w_p654.nc', mode='r')
plt.plot(mf.variables["w2"][96,0,:-1],fh.variables["zTop"][0,0,:],'--b',linewidth=2.5)

mf= Dataset(path_adc+'adcTurbulenceArrays_c16_tauVel_cslow_w_1.nc', mode='r')
plt.plot(mf.variables["w2"][96,0,:-1],fh.variables["zTop"][0,0,:],':c',linewidth=2.5)





plt.legend(["old_code_cslow_w_0.654","old_code_cslow_w_1","new_code_cslow_w_0.654","new_code_cslow_w_1"])
plt.ylim(-d,1);
plt.xlabel('$\overline{\\theta}$ $(^0C)$',fontsize=20)
plt.grid()
plt.xticks(fontsize=20); plt.yticks(fontsize=20)
# Out:
# (array([-70., -60., -50., -40., -30., -20., -10.,   0.,  10.]),
#  [Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, '')])

# %%
path_adc= "/Users/amrapalli/Desktop/DATA_ADC_paper1/rev_additional_plots/"
fig = plt.figure(figsize=(15,6))




# plt.subplot(152)
# fh=Dataset(path_adc+'output.0001-01-01_00.00.00_ener_cons_dtm1_5d.nc', mode='r')
# mf= Dataset(path_adc+'adcTurbulenceArrays_ener_cons_dtm1_5d.nc', mode='r')
# plt.plot(mf.variables["temperature"][0,0,:],fh.variables["zMid"][0,0,:],'-k',linewidth=2.5)
# plt.plot(mf.variables["temperature"][24,0,:],fh.variables["zMid"][0,0,:],'--r',linewidth=2.5)
# #plt.plot(mf.variables["temperature"][7200,0,:],fh.variables["zMid"][0,0,:],'--b',linewidth=2.5)
# plt.legend(['initial','1 hr','2 day'])
# plt.title('dT=-1.0')

plt.subplot(154)
fh=Dataset(path_adc+'output.0001-01-01_00.00.00_ener_cons_dtm5_5d.nc', mode='r')
mf= Dataset(path_adc+'adcTurbulenceArrays_ener_cons_dtm5_5d.nc', mode='r')
plt.plot(mf.variables["temperature"][0,0,:],fh.variables["zMid"][0,0,:],'-k',linewidth=2.5)
plt.plot(mf.variables["temperature"][24,0,:],fh.variables["zMid"][0,0,:],'--r',linewidth=2.5)
#plt.plot(mf.variables["temperature"][7200,0,:],fh.variables["zMid"][0,0,:],'--b',linewidth=2.5)
plt.legend(['initial','1 day','2 day'])
plt.title('dT=-5.0')
# Out:
# Text(0.5, 1.0, 'dT=-5.0')

# %%
mf.variables["temperature"].shape
124213/3600
# Out:
# 34.50361111111111

# %%
T_f=mf.variables["temperature"][24,0,:]
T_i=20-5*fh.variables["zMid"][0,0,:]

np.trapz(T_f-T_i,fh.variables["zMid"][0,0,:])
# Out:
# 1.1206927859572602

# %%
fh=Dataset(path_adc+'output.0001-01-01_00.00.00_ener_cons_dtm5_5d.nc', mode='r')
mf= Dataset(path_adc+'adcTurbulenceArrays_ener_cons_dtm5_5d.nc', mode='r')
plt.plot(T_i,fh.variables["zMid"][0,0,:],'-k',linewidth=2.5)
plt.plot(T_f,fh.variables["zMid"][0,0,:],'--r',linewidth=2.5)
#plt.plot(mf.variables["temperature"][7200,0,:],fh.variables["zMid"][0,0,:],'--b',linewidth=2.5)
plt.legend(['initial','1 day'],fontsize=20)
plt.title('dT=-5.0',fontsize=20)
plt.xlabel("Temperature $(^0C)$",fontsize=20)
plt.ylabel("Depth (m)",fontsize=20)
plt.xticks(fontsize=20); plt.yticks(fontsize=20)
# Out:
# (array([-120., -100.,  -80.,  -60.,  -40.,  -20.,    0.,   20.]),
#  [Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, '')])

# %%
np.nansum(T_f-T_i)
# Out:
# 4.814637577510439e-11

# %%
np.trapz(T_f-T_i,fh.variables["zMid"][0,0,:])= 1.1206927859572602
# Out:
#   Input In [19]
#     np.trapz(T_f-T_i,fh.variables["zMid"][0,0,:])= 1.1206927859572602
#     ^
# SyntaxError: cannot assign to function call
